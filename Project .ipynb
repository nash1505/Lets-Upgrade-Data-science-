# %% [markdown]
# # Project

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pubg = pd.read_csv("pubg - Dr. Darshan Ingle.csv")
pubg
# Out:
#                   Id         groupId         matchId  assists  boosts  \
# 0     2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1     a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2     1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3     f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4     c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
# 5     fd034582dd4d2e  9b8930aeee086a  6f6e52b15ddf21        0       1
# 6     c60b5633f4dcc8  7c0f817f6627c7  3232c1e0fec04b        0       3
# 7     f0ba8246b6980f  7318b5204462cb  112e9711f86001        0       0
# 8     79c5d5eda1c72e  a85b81198dfc06  ef5fc25e28ffb1        1       4
# 9     94834a28e52abd  bc513cde35fa54  f36a754a9b88f7        1       1
# 10    f051dcc9b0b3ce  d203c0e3d8c321  89a6a8738190b4        0       0
# 11    f02c2f34accf08  22ed911205c815  559dac9580b92a        1       0
# ...

# %%
print(pubg.columns)
print(pubg.values)
print(type(pubg.values))
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')
# [['2f262dd9795e60' '78437bcd91d40e' 'd5db3a49eb2955' ... 0 1470 0.0]
#  ['a32847cf5bf34b' '85b7ce5a12e10b' '65223f05c7fdb4' ... 2 1531 0.2222]
#  ['1b1900a9990396' 'edf80d6523380a' '1cadec4534f30a' ... 10 0 0.8571]
#  ...
#  ['a0a31a0b1dcbe1' '8d50c64ccc5071' '147e4bbb62e3bb' ... 2 1434 0.2083]
#  ['f6874657399d69' 'd31843d7e62ccb' '662567dcf280f5' ... 5 1534 0.2449]
#  ['90359b0b8f8b0d' '61d5b1bb8da43f' '258bfa48d88014' ... 1 0 0.1875]]
# <class 'numpy.ndarray'>

# %%
pubg.describe()
# Out:
#             assists        boosts   damageDealt        DBNOs  headshotKills  \
# count  10000.000000  10000.000000  10000.000000  10000.00000   10000.000000
# mean       0.234600      1.088500    129.211264      0.64400       0.221700
# std        0.575149      1.703279    167.193945      1.09562       0.577046
# min        0.000000      0.000000      0.000000      0.00000       0.000000
# 25%        0.000000      0.000000      0.000000      0.00000       0.000000
# 50%        0.000000      0.000000     83.805000      0.00000       0.000000
# 75%        0.000000      2.000000    185.325000      1.00000       0.000000
# max        7.000000     18.000000   3469.000000     11.00000      14.000000
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       1.354000     47.663100    506.970200      0.913400      0.543800
# ...

# %%
pubg.info
# Out:
# <bound method DataFrame.info of                   Id         groupId         matchId  assists  boosts  \
# 0     2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1     a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2     1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3     f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4     c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
# 5     fd034582dd4d2e  9b8930aeee086a  6f6e52b15ddf21        0       1
# 6     c60b5633f4dcc8  7c0f817f6627c7  3232c1e0fec04b        0       3
# 7     f0ba8246b6980f  7318b5204462cb  112e9711f86001        0       0
# 8     79c5d5eda1c72e  a85b81198dfc06  ef5fc25e28ffb1        1       4
# 9     94834a28e52abd  bc513cde35fa54  f36a754a9b88f7        1       1
# 10    f051dcc9b0b3ce  d203c0e3d8c321  89a6a8738190b4        0       0
# 11    f02c2f34accf08  22ed911205c815  559dac9580b92a        1       0
# ...

# %%
numeric = pubg.describe().columns

# %%
df = pubg[numeric]
df
# Out:
#       assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 0           0       0         0.00      0              0      0         92
# 1           0       0       163.20      1              1      0         42
# 2           0       3       278.70      2              1      8         16
# 3           0       0       191.90      1              0      0         31
# 4           0       0       100.00      1              0      0         87
# 5           0       1       200.00      2              0      1         73
# 6           0       3       638.20      4              1      1          1
# 7           0       0        27.94      0              0      0         66
# 8           1       4       275.80      3              0      4         10
# 9           1       1       530.40      4              0      8          5
# 10          0       0        20.59      0              0      0         48
# ...

# %%
pubg.describe()
# Out:
#             assists        boosts   damageDealt        DBNOs  headshotKills  \
# count  10000.000000  10000.000000  10000.000000  10000.00000   10000.000000
# mean       0.234600      1.088500    129.211264      0.64400       0.221700
# std        0.575149      1.703279    167.193945      1.09562       0.577046
# min        0.000000      0.000000      0.000000      0.00000       0.000000
# 25%        0.000000      0.000000      0.000000      0.00000       0.000000
# 50%        0.000000      0.000000     83.805000      0.00000       0.000000
# 75%        0.000000      2.000000    185.325000      1.00000       0.000000
# max        7.000000     18.000000   3469.000000     11.00000      14.000000
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       1.354000     47.663100    506.970200      0.913400      0.543800
# ...

# %% [raw]
# the average person kills  0.913400

# %%
pubg['total_kills'] = pubg['headshotKills'] + pubg['kills'] +pubg['teamKills'] 
pubg.describe()
# Out:
#             assists        boosts   damageDealt        DBNOs  headshotKills  \
# count  10000.000000  10000.000000  10000.000000  10000.00000   10000.000000
# mean       0.234600      1.088500    129.211264      0.64400       0.221700
# std        0.575149      1.703279    167.193945      1.09562       0.577046
# min        0.000000      0.000000      0.000000      0.00000       0.000000
# 25%        0.000000      0.000000      0.000000      0.00000       0.000000
# 50%        0.000000      0.000000     83.805000      0.00000       0.000000
# 75%        0.000000      2.000000    185.325000      1.00000       0.000000
# max        7.000000     18.000000   3469.000000     11.00000      14.000000
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       1.354000     47.663100    506.970200      0.913400      0.543800
# ...

# %% [raw]
# 99% people kills at least 0 kills and maximum 49 kills (including the team kills)

# %%
pubg['kills'].max()
# Out:
# 35

# %% [raw]
# the maximum kill ever recorded is 35

# %%
df
# Out:
#       assists  boosts  damageDealt  DBNOs  headshotKills  heals  killPlace  \
# 0           0       0         0.00      0              0      0         92
# 1           0       0       163.20      1              1      0         42
# 2           0       3       278.70      2              1      8         16
# 3           0       0       191.90      1              0      0         31
# 4           0       0       100.00      1              0      0         87
# 5           0       1       200.00      2              0      1         73
# 6           0       3       638.20      4              1      1          1
# 7           0       0        27.94      0              0      0         66
# 8           1       4       275.80      3              0      4         10
# 9           1       1       530.40      4              0      8          5
# 10          0       0        20.59      0              0      0         48
# ...

# %%
df.columns
# Out:
# Index(['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals',
#        'killPlace', 'killPoints', 'kills', 'killStreaks', 'longestKill',
#        'matchDuration', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %%
df['matchDuration']
# Out:
# 0       1376
# 1       1370
# 2       1381
# 3       1708
# 4       1807
# 5       1362
# 6       1369
# 7       1349
# 8       1387
# 9       1377
# 10      1358
# 11      1829
# 12      1385
# 13      1778
# 14      1863
# 15      1336
# 16      1898
# 17      1793
# 18      1351
# 19      1421
# 20      1771
# 21      1279
# 22      1393
# 23      1904
# 24      1384
# 25      1311
# 26      1883
# 27      1382
# 28      2175
# 29      1964
#         ...
# 9970    2026
# 9971    1810
# 9972    1219
# 9973    1308
# 9974    1442
# 9975    1871
# 9976    1820
# 9977    1422
# 9978    1365
# 9979    1853
# 9980    1872
# 9981    1964
# 9982    1360
# 9983    1310
# 9984    1274
# 9985    1437
# 9986    1395
# 9987    1755
# 9988    1436
# 9989    1775
# 9990    1311
# 9991    1890
# 9992    1923
# 9993    1338
# 9994    1331
# 9995    1288
# 9996    1906
# 9997    1344
# 9998    1355
# 9999    1416
# Name: matchDuration, Length: 10000, dtype: int64

# %%
df['matchDuration'].max()
# Out:
# 2202

# %%
df['matchDuration'].describe()
# Out:
# count    10000.000000
# mean      1575.398000
# std        258.963515
# min        464.000000
# 25%       1366.000000
# 50%       1431.500000
# 75%       1849.250000
# max       2202.000000
# Name: matchDuration, dtype: float64

# %%
df['matchDuration'].min()
# Out:
# 464

# %% [raw]
# the datatype of match duration is int64 the maximum duration ever recorded is 2202 and least duration is 464
# 50% matches are having duration is 1431.50

# %%
sns.distplot( pubg['matchDuration'] );

# %%
sns.distplot( pubg['walkDistance'] );

# %%
pubg['walkDistance'].max()
# Out:
# 10490.0

# %%
pubg['walkDistance'].min()
# Out:
# 0.0

# %%
pubg['walkDistance'].describe()
# Out:
# count    10000.000000
# mean      1130.008410
# std       1168.597983
# min          0.000000
# 25%        151.575000
# 50%        650.350000
# 75%       1923.250000
# max      10490.000000
# Name: walkDistance, dtype: float64

# %% [raw]
# the maximum walk distance is 10490 and minimum is 0.0 50% players walks 650.35

# %%
sns.distplot( pubg['matchDuration'] );
sns.distplot( pubg['walkDistance'] );

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(pubg['matchDuration'],'-')

plt.subplot(2,1,2)
plt.plot(pubg['walkDistance'],"--");

# %%
plt.figure(figsize=(20,2))
plt.subplot(1,2,1)
plt.plot(pubg['matchDuration'],'-')

plt.subplot(1,2,2)
plt.plot(pubg['walkDistance'],"--");

# %%
sns.pairplot(pubg);

# %%
pubg['matchType'].unique()
# Out:
# array(['squad-fpp', 'squad', 'duo-fpp', 'solo-fpp', 'duo', 'solo',
#        'crashfpp', 'flaretpp', 'normal-squad-fpp', 'normal-duo-fpp',
#        'flarefpp', 'normal-squad', 'normal-solo-fpp', 'crashtpp'],
#       dtype=object)

# %% [raw]
# the unique values in the column matchType is given above and there are 1000 matchType and

# %%
sns.barplot(x='matchType', y='killPoints', data=pubg);
plt.xticks(rotation=70);

# %%
sns.barplot(x='matchType', y='weaponsAcquired', data=pubg);
plt.xticks(rotation=70);

# %%
pubg.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc', 'total_kills'],
#       dtype='object')

# %% [raw]
# the categorical data is matchType

# %%
pubg['matchType'].value_counts()
# Out:
# squad-fpp           3969
# duo-fpp             2282
# squad               1359
# solo-fpp            1234
# duo                  702
# solo                 386
# normal-squad-fpp      24
# normal-duo-fpp        13
# crashfpp              13
# normal-solo-fpp        8
# normal-squad           4
# flaretpp               3
# crashtpp               2
# flarefpp               1
# Name: matchType, dtype: int64

# %%
sns.boxplot(x='matchType', y='kills', data=pubg);
plt.xticks(rotation=70);

# %%
sns.boxplot(x='matchType', y='winPlacePerc', data=pubg);
plt.xticks(rotation=90);

# %%
sns.boxplot(x='matchType', y='matchDuration', data=pubg);
plt.xticks(rotation=90);

# %%
pubg['KILL'] = pubg['headshotKills'] + pubg['teamKills'] + pubg['roadKills']
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1  a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2  1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3  f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4  c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  roadKills  \
# 0          0.0      0              0      0         92  ...          0
# 1        163.2      1              1      0         42  ...          0
# 2        278.7      2              1      8         16  ...          0
# 3        191.9      1              0      0         31  ...          0
# 4        100.0      1              0      0         87  ...          0
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance weaponsAcquired  \
# ...

# %%
pubg['winPlacePerc'] = round(pubg['winPlacePerc'] , 3)
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  2f262dd9795e60  78437bcd91d40e  d5db3a49eb2955        0       0
# 1  a32847cf5bf34b  85b7ce5a12e10b  65223f05c7fdb4        0       0
# 2  1b1900a9990396  edf80d6523380a  1cadec4534f30a        0       3
# 3  f589dd03b60bf2  804ab5e5585558  c4a5676dc91604        0       0
# 4  c23c4cc5b78b35  b3e2cd169ed920  cd595700a01bfa        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  roadKills  \
# 0          0.0      0              0      0         92  ...          0
# 1        163.2      1              1      0         42  ...          0
# 2        278.7      2              1      8         16  ...          0
# 3        191.9      1              0      0         31  ...          0
# 4        100.0      1              0      0         87  ...          0
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance weaponsAcquired  \
# ...

# %%
pubg['damageDealt'].sample(50)
# Out:
# 9075       0.000
# 6658    1007.000
# 4849       0.000
# 8644     529.200
# 45         0.000
# 6274       0.000
# 4895       0.000
# 6335     142.100
# 1618     528.600
# 6005       0.000
# 6365     100.000
# 1134     485.800
# 8830       7.204
# 7274     208.700
# 4915     180.100
# 3124       0.000
# 3473       0.000
# 1908      78.690
# 1247     161.900
# 7900     389.500
# 2940      88.000
# 152      208.700
# 2829      70.560
# 148      100.000
# 5335       0.000
# 4329     100.000
# 432      374.600
# 4592     591.200
# 5233     544.400
# 961        0.000
# 6563       0.000
# 8964     100.000
# 4476       0.000
# 5785     345.500
# 5181     142.600
# 4883     100.000
# 2431       0.000
# 3775     153.200
# 105       98.490
# 7587     497.100
# 1995       0.000
# 2183     549.600
# 7399      72.440
# 9312     546.300
# 604      100.000
# 9087      48.360
# 6713       0.000
# 211      186.700
# 1415     227.400
# 5866      50.650
# Name: damageDealt, dtype: float64

# %%
pubg['damageDealt'].sample(50).mean()
# Out:
# 153.525

# %%
x = pubg['damageDealt'].sample(50)*100

# %%
pubg['damageDealt'].sample(50).mean()*100
# Out:
# 13654.160000000005

# %%
plt.hist(x);

# %%
sns.distplot( x );
